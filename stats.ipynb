# %%
import matplotlib.pyplot as plt

# %%
stats = [{'epoch': 1,
  'Training Loss': 0.24790016317986494,
  'Valid. Loss': 0.1080904268766427,
  'Valid. Accur.': 0.9620,
  'Training Time': '0:07:50',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2107.7500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9368},
 {'epoch': 2,
  'Training Loss': 0.08422887178500889,
  'Valid. Loss': 0.0847216107963012,
  'Valid. Accur.': 0.9767,
  'Training Time': '0:07:49',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2162.5000,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9611},
 {'epoch': 3,
  'Training Loss': 0.04046000401104587,
  'Valid. Loss': 0.057625928122526524,
  'Valid. Accur.': 0.9859,
  'Training Time': '0:07:48',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2197.5000,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9767},
 {'epoch': 4,
  'Training Loss': 0.020269569003104847,
  'Valid. Loss': 0.057986818752281226,
  'Valid. Accur.': 0.9889,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2210.7500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9826},
 {'epoch': 5,
  'Training Loss': 0.010900341483047643,
  'Valid. Loss': 0.05217687229599789,
  'Valid. Accur.': 0.9910,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2218.7500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9861},
 {'epoch': 6,
  'Training Loss': 0.00877978862599633,
  'Valid. Loss': 0.05610461406520085,
  'Valid. Accur.': 0.9910,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2219.2500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9863},
 {'epoch': 7,
  'Training Loss': 0.0064636379559114086,
  'Valid. Loss': 0.05978216292561999,
  'Valid. Accur.': 0.9910,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2219.2500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9863},
 {'epoch': 8,
  'Training Loss': 0.002940902894476739,
  'Valid. Loss': 0.059888917059020726,
  'Valid. Accur.': 0.9926,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2227.7500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9901},
 {'epoch': 9,
  'Training Loss': 0.00256361286187162,
  'Valid. Loss': 0.06080118452857254,
  'Valid. Accur.': 0.9924,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2224.,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9884},
 {'epoch': 10,
  'Training Loss': 0.0021962806324301856,
  'Valid. Loss': 0.05602230718497571,
  'Valid. Accur.': 0.9930,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2228.2500,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9903},
 {'epoch': 11,
  'Training Loss': 0.0011984733529678598,
  'Valid. Loss': 0.05397912736531276,
  'Valid. Accur.': 0.9936,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2228.,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9902},
 {'epoch': 12,
  'Training Loss': 0.0005834258095816573,
  'Valid. Loss': 0.05836105281823157,
  'Valid. Accur.': 0.9934,
  'Training Time': '0:07:47',
  'Validation Time': '0:00:16',
  'Valid. FNC Score': 2229.5000,
  'Valid. Max FNC Score': 2250.,
  'Relative FNC Score': 0.9909}]

# %%
epoch = [x['epoch'] for x in stats]
training_loss = [x['Training Loss'] for x in stats]
validation_loss  = [x['Valid. Loss'] for x in stats]
relative_validation_fnc = [x['Relative FNC Score'] for x in stats]

# %%
plt.plot(epoch, training_loss, label='train')
plt.plot(epoch, validation_loss, label='validation')
plt.title('Loss over training epochs')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.savefig('loss.png')

# %%
plt.plot(epoch, relative_validation_fnc)
plt.title('Evaluation on Validation Set (max 1.00)')
plt.xlabel('epochs')
plt.ylabel('Relative FNC Score')
plt.savefig('fnc.png')

# %%
validation_accuracy = [x['Valid. Accur.'] for x in stats]

# %%
plt.plot(epoch, validation_accuracy)
plt.title('Accuracy on Validation Set')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.savefig('accuracy.png')
